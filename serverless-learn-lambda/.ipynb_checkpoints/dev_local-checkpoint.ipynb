# %%
from handler import run

# %%
run()
# Out:
# ... cmd to execute:
# echo Hello!
# ... result:
# Hello!
#
# ... cmd to execute:
# ls
# ... result:
# Error: failed to execute command: ls
# b"'ls' is not recognized as an internal or external command,\r\noperable program or batch file.\r\n"
#
# ... cmd to execute:
# pip freeze
# ... result:
# absl-py==0.7.0
# altair==3.1.0
# asn1crypto==0.24.0
# astor==0.7.1
# atomicwrites==1.3.0
# attrs==19.1.0
# awscli==1.16.207
# backcall==0.1.0
# bleach==3.1.0
# bokeh==1.0.4
# botocore==1.12.197
# branca==0.3.1
# certifi==2019.6.16
# cffi==1.12.3
# chardet==3.0.4
# Click==7.0
# click-plugins==1.1.1
# cligj==0.5.0
# colorama==0.3.9
# cryptography==2.7
# cycler==0.10.0
# decorator==4.3.2
# descartes==1.1.0
# docutils==0.14
# entrypoints==0.3
# fastparquet==0.3.1
# Fiona==1.8.4
# folium==0.9.1
# future==0.17.1
# gast==0.2.2
# GDAL==2.3.3
# geopandas==0.5.1
# grpcio==1.16.1
# h5py==2.9.0
# idna==2.8
# importlib-metadata==0.17
# ipykernel==5.1.0
# ipython==7.2.0
# ipython-genutils==0.2.0
# ...
